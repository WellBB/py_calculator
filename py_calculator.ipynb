# %% [markdown]
# # First code developed in python

# %%
# Calculator in Python

print('\n*************** Python Calculator ***************')

print('\nSelect the desired operation number:\n')

print('1 - Sum')
print('2 - Subtraction')
print('3 - Multiplication')
print('4 - Division')

chosenOption = []
chosenOption.append(input('\nEnter your choice (1/2/3/4):'))
try:
    chosenOption[0] = int(chosenOption[0])
    while not chosenOption[0] == 1 and not chosenOption[0] == 2 and not chosenOption[0] == 3 and not chosenOption[0] == 4 or type(chosenOption[0]) != type(1):
        print('\nInvalid option!')
        chosenOption.clear()
        chosenOption.append(input('\nPlease enter a valid option (1/2/3/4)'))
        try:
            chosenOption[0] = int(chosenOption[0])
        except:
            continue
except:
    while not chosenOption[0] == 1 and not chosenOption[0] == 2 and not chosenOption[0] == 3 and not chosenOption[0] == 4 or type(chosenOption[0]) != type(1):
        print('\nInvalid option!')
        chosenOption.clear()
        chosenOption.append(input('\nPlease enter a valid option (1/2/3/4)'))
        try:
            chosenOption[0] = int(chosenOption[0])
        except:
            continue

def operationWithNumber(var):
    try:
        var[0] = float(var[0])
        while var[0] == 0 and chosenOption[0] == 4 or type(var[0]) != type(1.1):
            print('\nInvalid option!')
            var.clear()
            var.append(input('\nPlease enter a valid or non-zero number:'))
            try:
                var[0] = float(var[0])
            except:
                continue
    except:
        while var[0] == 0 and chosenOption[0] == 4 or type(var[0]) != type(1.1):
            print('\nInvalid option!')
            var.clear()
            var.append(input('\nPlease enter a valid or non-zero number:'))
            try:
                var[0] = float(var[0])
            except:
                continue

firstNumber = []
firstNumber.append(input('\nEnter the first number:'))
operationWithNumber(firstNumber)

secondNumber = []
secondNumber.append(input('\nEnter the second number:'))
operationWithNumber(secondNumber)

print('')

if chosenOption[0] == 1:
    result = firstNumber[0] + secondNumber[0]
    print(firstNumber[0], ' + ', secondNumber[0], ' = ', round(result, 3))
elif chosenOption[0] == 2:
    result = firstNumber[0] - secondNumber[0]
    print(firstNumber[0], ' - ', secondNumber[0], ' = ', round(result, 3))
elif chosenOption[0] == 3:
    result = firstNumber[0] * secondNumber[0]
    print(firstNumber[0], ' * ', secondNumber[0], ' = ', round(result, 3))
elif chosenOption[0] == 4:
    result = firstNumber[0] / secondNumber[0]
    print(firstNumber[0], ' / ', secondNumber[0], ' = ', round(result, 3))

print('')

print('Thank you for using this calculator!')
